# %% [markdown]
# Exploring of Interference in Two or More Actual Wide Slits Experiment

# %%
# %%capture 
# %pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, FloatSlider, IntSlider


def func(x, a, g, N, λ):
    numerator1 = np.sin((a / λ) * np.pi * np.sin(x))
    denominator1 = np.pi * (a / λ) * np.sin(x)
    term1 = (numerator1 / denominator1)**2

    numerator2 = np.sin((g / λ) * np.pi * N * np.sin(x))
    denominator2 = np.sin(np.pi * (g / λ) * np.sin(x))
    term2 = (numerator2 / denominator2)**2

    result = 0.15 * term1 * term2
    return result


def plot_func(a, g, N, λ):
    f = lambda x: func(x, a, g, N, λ)
    x = np.linspace(-1, 1, 1000)
    y = np.array(list(map(f, x)))

    plt.plot(x, y)
    plt.grid(True)
    plt.show()


a_slider = FloatSlider(value=0.4, min=0.4, max=2, step=0.01, description='a:')
g_slider = FloatSlider(value=2, min=2, max=6, step=0.01, description='g:')
N_slider = IntSlider(value=1, min=1, max=10, step=1, description='N:')
λ_slider = FloatSlider(value=0.4, min=0.4, max=0.8, step=0.1, description='λ:')

interact(plot_func, a=a_slider, g=g_slider, N=N_slider, λ=λ_slider)
pass
# Out:
# interactive(children=(FloatSlider(value=0.4, description='a:', max=2.0, min=0.4, step=0.01), FloatSlider(value…

# %% [markdown]
# Interference in two wide slits separated by a certain distance. A decrease in the intensity of maxima is caused by diffraction effects.

# %%
from IPython.display import YouTubeVideo
video = YouTubeVideo("7teZ_qU0III", width=700,height=600)
display(video)

# %% [markdown]
# Intensity distribution at three-slit experimental setting is visualised in real-time in the DataGraph-Window of the DMSRP. A video shows a dynamic visualisation.

# %%
from IPython.display import YouTubeVideo
video = YouTubeVideo("I2H63bnTVHA", width=700,height=600)
display(video)

# %% [markdown]
# Intensity distribution at four-slit experimental setting is visualised in real-time in the DataGraph-Window of the DMSRP. A video shows a dynamic visualisation.

# %%
from IPython.display import YouTubeVideo
video = YouTubeVideo("k8rAGyqXAX4", width=700,height=600)
display(video)
